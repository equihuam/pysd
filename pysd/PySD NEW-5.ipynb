# %%
import numpy as np
import regex as re
import utils
import textwrap
import parsimonious

# %%
with open('STAMPS MPOT v32g.dyn','rU') as in_file:
    text=in_file.read()
text=re.sub(r'(?i)MACRO[\s\S]*MEND','',text)
text=re.sub(r'\*+ {2}Group.*','',text)

# %%
#deprecated, too slow
def if_then_else(text):
    try:
        valuetounpack=re.findall('(?i)(?!.{2}.*?if)(if.*?then.*?else.*?)(then|else|$)',text)[-1][0]
        unpacked=filter(None,[x.strip() for x in re.split(r'(?i)if|then|else',valuetounpack)])
        text=text.replace(valuetounpack,'_conditional(%s)'%','.join(unpacked))
        return if_then_else(text)
    except:
        return text
    
def if_then_else(text):
    try:
        valuetounpack=re.findall('(?i)((\W|if|then|else) *)(if.*?then.*?else.*?)(then|else|$)',
                                 text,overlapped=True)[-1][2]
        unpacked=filter(None,[x.strip() for x in re.split(r'(?i)then|else',valuetounpack[2:])])
        text=text.replace(valuetounpack,'_conditional(%s)'%','.join(unpacked))
        return if_then_else(text)
    except:
        return text

# %%
functiondic={'MAX':'np.maximum','MIN':'np.minimum','SUM':'np.sum','if_then_else':'np.where',
             'SUMV':'functions.sumv','ABS':'abs', 'INTEGER':'int','EXP':'np.exp','PI':'np.pi', 
             'SIN':'np.sin', 'COS':'np.cos','SQRT':'np.sqrt', 'TAN':'np.tan', 'LOGN':'np.random.lognormal',
             'RANDOM NORMAL':'functions.bounded_normal','POISSON':'np.random.poisson','LN':'np.log', 
             'EXPRND':'np.random.exponential','RANDOM UNIFORM':'np.random.rand','ARCCOS':'np.arccos',
             'ARCSIN':'np.arcsin','ARCTAN':'np.arctan','STEP':'functions.step', 'MODULO':'np.mod', 
             'PULSE':'functions.pulse', 'PULSE TRAIN':'functions.pulse_train','RAMP':'functions.ramp', 
             'FIFZE':'functions.fifze', 'FIFGE':'functions.fifge','SCLPRD':'functions.sclprd', 
             'PRDV':'functions.prdv','SMOOTH3I':'smooth3i','SMOOTH3':'smooth3','SMOOTHI':'smoothi',
             'SMOOTH':'smooth','LOGN':'np.log', 'ROUND':'np.round','DELAY3I':'delay3i','DELAY3':'delay3',
             'DELAY1I':'delayi','DELAY1':'delay','DELAYI':'delayi','DELAY':'delay','FLOOR':'np.floor',
             'VECTORMIN':'np.min','VECTORMAX':'np.max','PROD':'np.prod','TABHL':'functions.tabhl',
             'POS':'pos','MISSING()':'0','TUNE1':'tune1','_conditional':'if_then_else'
            }
functiondic={x.lower():functiondic[x].lower() for x in functiondic.keys()}

# %%
model_all=[x[0] for x in re.findall(r'([A-Z]+ +.+(\n {5}.+)*)',text)]
model_vars=[x for x in model_all if re.match('(C|A|T|R|L|N|SPEC)\s',x)]

#Subscripts
model_subs=[re.sub(r'\n\s{5}','',x[5:]) for x in model_all if x.startswith('FOR')]
model_subs={x.split('=',1)[0]:x.split('=',1)[-1].split(',') for x in model_subs}
for key,value in model_subs.iteritems():
    if len(value)==1 and re.search('-',value[0]):
        value=value[0]
        if not re.search(r'[a-zA-Z]',value):
            start=int(value.split('-')[0])
            stop=int(value.split('-')[-1])+1
            model_subs[key]=[str(x) for x in range(start,stop)]
        else:
            start=value.split('-')[0]
            stop=value.split('-')[-1]
            base=[x for x,y in model_subs.iteritems() if x!=key and start in y and stop in y]
            base=model_subs[base[0]]
            model_subs[key]=[x for x in base if base.index(x)>=base.index(start) 
                             and base.index(x)<=base.index(stop)]

model_subs_list=[str(x) for x in set(reduce(lambda x,y:x+y,model_subs.values())+model_subs.keys()+['!'])]
model_subs_list='|'.join(model_subs_list)

# %%
model_list=[str(x) for x in set(reduce(lambda x,y:x+y,model_subs.values())+model_subs.keys())]
[model_list.append(re.findall(r'[A-Z]+ +([^=\(]+)[=\(]',x)[0]) for x in model_vars]
[model_list.append(x) for x in functiondic.keys()]
model_list=[x.lower() for x in model_list]
model_list=set(model_list)

# %%
def cleanup(function,compareset):
    number=r'[e\d]+'
    func=''.join(function)
    for variable in re.split(r'[^\w ]+',func.split(' ',1)[-1].strip()):
        variable=variable.strip().lower()
        if len(function)>1 and variable:
            if re.match(r'\(\W+\)',function[-1]) \
            or variable not in compareset \
            and not re.match(number,variable) \
            and not re.search('if|then|else',variable):
                return cleanup(function[:-1],compareset)
    return func

# %%
# %%prun
classify={'C':'constants','A':'auxiliaries','T':'tables','R':'rates',
          'L':'levels','N':'initials','SPEC':'specs'}

model=[x.strip().split('\n     ') for x in model_vars] #OR MAYBE {6}
model=[cleanup(x,model_list) for x in model]
model=[re.sub(r'(\()([\w ]+,)*(\*)(,[\w ]+)*(\))',r'\1\2!\4\5',x) for x in model]
model=[re.sub(r'(?i)\(((%s)(,(%s))*)\)'%(model_subs_list,model_subs_list),r'[\1]',x) for x in model]
model=[if_then_else(x) for x in model]
model=[re.sub(r'([\w ]+\=)([\w ]+\+ *DT *\*)(\(.*\))',r'\1INTEG\3',x) for x in model]
datadictionary={classify[x]:[y.split(' ',1)[-1].strip() for y in model 
                             if re.match('\w+',y).group()==x] 
                for x in set(classify.keys())}
# model=[x.split(' ',1)[-1].strip() for x in model]

# %%
components=['kind','real_name','subs','expr']
entries=[dict(zip(components,list(re.match(r'(\w+) +([\w ]+)\[?(.*?)\]?\=(.*)',x).groups()))) for x in model]
for x in entries:
    x.update({'subs':filter(None,x['subs'].split(','))})

# %%
namespace = {'TIME': 'time', 'Time': 'time'}  # Initialize with builtins
for element in entries:
    if element['kind'] not in ['T', 'FOR']:
        element['py_name'], namespace = utils.make_python_identifier(element['real_name'],
                                                                     namespace)

# %%
parse_general_expression(entries[10],namespace,model_subs)
# entries[10]
# temp['expr']=temp['expr'].replace(')',',0)')
# datadictionary['levels']
# for i in range(len(entries)):
#     if entries[i]['real_name']=='Cumulative Costs':
#         print i
# Out:
# ({'arguments': '',
#   'kind': 'constant',
#   'py_expr': "xr.DataArray(data=[46620.5],\n             coords={'RR': ['Rank 1']},\n             dims=['RR'] )"},
#  [])

# %%
model
# Out:
# ['L  Cumulative Costs=INTEG(Cost Rate) ',
#  'N  Cumulative Costs=0 ',
#  'R  Cost Rate=Total Costs ',
#  'A  Total Costs=Recruiting and Enlistment Costs+Total Manpower Costs+Total Retention Costs+Facilities Costs+Classroom Costs+Separation Costs ',
#  'A  Recruiting and Enlistment Costs=Recruiting Personnel Costs+Enlistment Bonuses ',
#  'A  Recruiting Personnel Costs=Cost per Recruiter*Number of Recruiters ',
#  'C  Cost per Recruiter=60000 ',
#  'A  Enlistment Bonuses=Recruiting Rate*Normal Bonus per Recruit*Effect on Bonus of Recruit Qlty*Effect on Bonus of Economic Conditions ',
#  'A  Total Manpower Costs=sum(Manpower Personnel Costs by Rank[!]) ',
#  'A  Manpower Personnel Costs by Rank[Ranks]=Manpower Cost Per Person Per Year[Ranks]*Total Manpower by Rank[Ranks] ',
#  'C  Manpower Cost Per Person Per Year[Rank 1]=46620.5 ',
#  'C  Manpower Cost Per Person Per Year[Rank 2]=49691',
#  'C  Manpower Cost Per Person Per Year[Rank 3]=54661',
#  'C  Manpower Cost Per Person Per Year[Rank 4]=64966',
#  'C  Manpower Cost Per Person Per Year[Rank 5]=78820',
#  'C  Manpower Cost Per Person Per Year[Rank 6]=91797',
#  'C  Manpower Cost Per Person Per Year[Rank 7]=105214',
#  'C  Manpower Cost Per Person Per Year[Rank 8]=117577',
#  'C  Manpower Cost Per Person Per Year[Rank 9]=140450',
#  'A  Total Retention Costs=sum(Retention Costs[!]) ',
#  'A  Retention Costs[Ranks]=Normal Retention Costs[Ranks]*Reenlistment Incentives[Ranks] ',
#  'C  Normal Retention Costs[Ranks]=1000000 ',
#  'A  Facilities Costs=SUM(Facilities Costs by School) ',
#  'A  Classroom Costs=SUM(Classroom Costs by School) ',
#  'A  Separation Costs=0 ',
#  'L  Cumulative Retention Costs=INTEG(Retention Cost Rate) ',
#  'N  Cumulative Retention Costs=0 ',
#  'R  Retention Cost Rate=Total Retention Costs ',
#  'L  Cumulative Manpower Costs=INTEG(Manpower Cost Rate) ',
#  'N  Cumulative Manpower Costs=0 ',
#  'R  Manpower Cost Rate=Total Manpower Costs ',
#  'L  Cumulative Recruiting Costs=INTEG(Recruiting Costs) ',
#  'N  Cumulative Recruiting Costs=0 ',
#  'R  Recruiting Costs=Recruiting and Enlistment Costs ',
#  'L  Cumulative Facilities Costs=INTEG(Facility Costs Rate) ',
#  'N  Cumulative Facilities Costs=0 ',
#  'R  Facility Costs Rate=Facilities Costs ',
#  'L  Cumulative Classroom Costs=INTEG(Classroom Cost Rate) ',
#  'N  Cumulative Classroom Costs=0 ',
#  'R  Classroom Cost Rate=Classroom Costs ',
#  'L  Cumulative Separation Costs=INTEG(Separation Cost Rate) ',
#  'N  Cumulative Separation Costs=0 ',
#  'R  Separation Cost Rate=Separation Costs ',
#  'A  Effect on Bonus of Recruit Qlty=Effect on Bonuses of ASVAB Scores(Average ASVAB of A School Students) ',
#  'T  Effect on Bonuses of ASVAB Scores=0,1 ',
#  'C  Normal Bonus per Recruit=5000 ',
#  'A  Effect on Bonus of Economic Conditions=Effect on Bonuses of Economic Conditions(Economic Conditions) ',
#  'T  Effect on Bonuses of Economic Conditions=0,1 ',
#  'A  Recruiting Rate=Number of Recruiters*Actual Recruiting Productivity*Mult on RR ',
#  'C  Mult on RR=1 ',
#  'L  Number of Recruiters=INTEG(Recruiter Hires-Recruiter Losses) ',
#  'N  Number of Recruiters=_conditional(Switch to Initialize Recruiters Automatically=0,Initial Recruiters,Desired Recruiters)',
#  'C  Switch to Initialize Recruiters Automatically=1 ',
#  'C  Initial Recruiters=755 ',
#  'A  Desired Recruiters=MAX(Minimum Recruiters,Desired Recruits/POS(Actual Recruiting Productivity)) ',
#  'C  Minimum Recruiters=1 ',
#  'A  Desired Recruits=_conditional(Switch to Test Structure=0,MAX(0,Staffing Gap/Time to Try to Close Recruitment Gap+Expected Losses to make up via recruiting),Test Desired Recruiting Rate)',
#  'C  Time to Try to Close Recruitment Gap=2 ',
#  'R  Recruiter Hires=Recruiter Hiring Rate ',
#  'A  Recruiter Hiring Rate=_conditional(Desired Change in Recruiters > 0,Desired Change in Recruiters/Time to Hire Recruiting Staff,0)',
#  'C  Time to Hire Recruiting Staff=0.5 ',
#  'A  Desired Change in Recruiters=(Constrained Desired Recruiters-Number of Recruiters) ',
#  'A  Constrained Desired Recruiters=MIN(Desired Recruiters, Max Recruiters Budget/Cost per Recruiter) ',
#  'R  Recruiter Losses=Recruiter Layoff Rate ',
#  'A  Recruiter Layoff Rate=_conditional(Desired Change in Recruiters < 0,MIN(Number of Recruiters,-Desired Change in Recruiters)/Time to Layoff Recruiting Staff,0)',
#  'C  Time to Layoff Recruiting Staff=0.25 ',
#  'A  Fraction of Population needed=Desired Recruits/Target Recruiting Population*100 ',
#  'A  Target Recruiting Population=US 18 to 24 yr old population(TIME)*Fraction of Normal Pop meeting ASVAB reqs ',
#  'T  US 18 to 24 yr old population=2.0005e+3,2.731527e+7, 2.0015e+3,2.799265e+7, 2.0025e+3,2.848071e+7, 2.0035e+3,2.891675e+7, 2.0045e+3,2.930218e+7, 2.0055e+3,2.944155e+7, 2.0065e+3,2.960284e+7, 2.0075e+3,2.980802e+7, 2.0085e+3,3.019427e+7, 2.0095e+3,3.053035e+7, 2.0105e+3,3.070821e+7, 2.0155e+3,3.0983e+7, 2.0205e+3,3.0028e+7, 2.0255e+3,3.018e+7, 2.0305e+3,3.0605e+7, 2.0355e+3,3.2125e+7, 2.0405e+3,3.3199e+7 ',
#  'A  Fraction of Normal Pop meeting ASVAB reqs=Table for ASVAB Distribution(ASVAB Cutoff) ',
#  'T  Table for ASVAB Distribution=0,1, 2e+1,9.99e-1, 3e+1,9.67e-1, 3.5e+1,9.33e-1, 4e+1,8.41e-1, 4.5e+1,6.91e-1, 5e+1,5e-1, 5.5e+1,3.09e-1, 6e+1,1.59e-1, 6.5e+1,6.7e-2, 7e+1,2.3e-2, 8e+1,1e-3 ',
#  'A  ASVAB Cutoff=70 ',
#  'A  Recruiter Gap=Number of Recruiters/Desired Recruiters ',
#  'A  Staffing Gap=Strength Target-Total Strength ',
#  'A  Expected Losses to make up via recruiting=Total Strength*Recent Attrition Rate ',
#  'A  Recent Attrition Rate=SMOOTH(Total Losses/Total Strength,Time to Measure Attrition) ',
#  'C  Time to Measure Attrition=.25 ',
#  'A  Test Desired Recruiting Rate=Desired Recruit Rate to Maintain Levels+Additional Recruiting Rate to Close Future Gap ',
#  'A  Desired Recruit Rate to Maintain Levels=Total Losses ',
#  'A  Additional Recruiting Rate to Close Future Gap=(Plan for Future Heads in E3 thru E9-Current Heads in E3 thru E9-A School Student Backlog)/Years into Future for Planning ',
#  'C  Years into Future for Planning=3 ',
#  'A  Plan for Future Heads in E3 thru E9=Data for Total EPA ',
#  'A  Current Heads in E3 thru E9=Total Strength E3 thru E9 ',
#  'C  Switch to Test Structure=0 ',
#  'A  Actual Recruiting Productivity=Normal Recruiting Productivity*Impact from Effects on Recruiter Productivity*Recent Effect of Incentives on Recruiting Pdy ',
#  'C  Normal Recruiting Productivity=10 ',
#  'A  Impact from Effects on Recruiter Productivity=Effect of Unemployment on Recruiting*Effect of recruiting target on difficulty to hire*Effect of ASVAB score on difficulty to hire ',
#  'A  Effect of recruiting target on difficulty to hire=TUNE1(Table for relative difficulty to hire(Fraction of Population needed),Tuner for difficulty to hire) ',
#  'T  Table for relative difficulty to hire=0,1, 1e-2,1e-1 ',
#  'C  Tuner for difficulty to hire=.1 ',
#  'A  Effect of ASVAB score on difficulty to hire=TUNE1(Table for relative difficulty to hire from ASVAB(Target Average ASVAB Score),Tuner for difficulty to hire from ASVAB) ',
#  'T  Table for relative difficulty to hire from ASVAB=0,1.2, 3e+1,1.1, 5e+1,1, 6.5e+1,9.5e-1, 8e+1,8e-1, 9e+1,5.5e-1, 9.5e+1,8e-2, 1e+2,5e-2 ',
#  'C  Tuner for difficulty to hire from ASVAB=1 ',
#  'A  Target Average ASVAB Score=Desired Average ASVAB Score*Recent Effect of Recruiter Gap on ASVAB Target ',
#  'A  Desired Average ASVAB Score=Table for Desired Average ASVAB Score(TIME) ',
#  'T  Table for Desired Average ASVAB Score=2.01e+3,5e+1, 2.02e+3,5e+1 ',
#  'A  Recent Effect of Recruiter Gap on ASVAB Target=_conditional(Switch for Recruiter Gap Impact on ASVAB Score=0,1,SMOOTH(Effect of Recruiter Gap on Average ASVAB Target,Time to Smooth Recruiter Effect on ASVAB Target)*Switch for Recruiter Gap Impact on ASVAB Score)',
#  'C  Switch for Recruiter Gap Impact on ASVAB Score=0 ',
#  'C  Time to Smooth Recruiter Effect on ASVAB Target=0.25 ',
#  'A  Effect of Recruiter Gap on Average ASVAB Target=T_Effect of Recruiter Gap on Target ASVAB Score(Recruiter Gap) ',
#  'N  Effect of Recruiter Gap on Average ASVAB Target=1 ',
#  'T  T_Effect of Recruiter Gap on Target ASVAB Score=0,0, 5e-1,9e-1, 1,1, 1.5,1.075, 2,1.1 ',
#  'A  Recent Effect of Incentives on Recruiting Pdy=SMOOTH(Effect of Incentives on Recruiting Productivity,Time to Smooth Enlistment Incentives Effect) ',
#  'C  Time to Smooth Enlistment Incentives Effect=.25 ',
#  'A  Effect of Incentives on Recruiting Productivity=TUNE1(T_Effect of Incentives on Recruiting Productivity(Actual vs Normal Enlistment Incentives),Tuner for Effect of Enlistment Incentives) ',
#  'T  T_Effect of Incentives on Recruiting Productivity=0,1, 1e-2,8.5e-1, 1,1, 2,1.15 ',
#  'C  Tuner for Effect of Enlistment Incentives=0 ',
#  'A  Actual vs Normal Enlistment Incentives=Enlistment Incentives Offered per Person/Normal Cost per Enlistment Bonus ',
#  'A  Enlistment Incentives Offered per Person=_conditional(Number of Enlistments Needed > 0,Enlistment incentives Offered/Number of Enlistments Needed,0)',
#  'A  Enlistment incentives Offered=Number of Enlistments Needed*Effective Cost per Enlistment Bonus*Effect of Funding Constraint on Enlistment Bonuses ',
#  'A  Number of Enlistments Needed=MAX(0,Desired Recruits) ',
#  'A  Effective Cost per Enlistment Bonus=Normal Cost per Enlistment Bonus*Enlistment Incentives ',
#  'C  Normal Cost per Enlistment Bonus=5000 ',
#  'A  Enlistment Incentives=Table for Recruiting Difficulty on Incentives(Impact from Effects on Recruiter Productivity) ',
#  'T  Table for Recruiting Difficulty on Incentives=-2e-1,6e-1, -1e-1,8e-1, 0,1, 1e-1,1.2 ',
#  'A  Effect of Funding Constraint on Enlistment Bonuses=_conditional(Total Enlistment Bonuses Desired > 0,MIN(1,Max Enlistment Bonus Budget/Total Enlistment Bonuses Desired),1)',
#  'A  Total Enlistment Bonuses Desired=Number of Enlistments Needed*Effective Cost per Enlistment Bonus ',
#  'A  Target in Grade Gap[Ranks]=(Target in Grade[Ranks]-Actual in Grade[Ranks])/POS(Target in Grade[Ranks]) ',
#  'A  Target in Grade[Ranks]=_conditional(Switch for Constant Manning=1,Initial Planned Manning[Ranks],_conditional(Switch for Table by Total=0,Data Based Input to Target[Ranks],Target for Total Strength*Planned Fraction by Grade[Ranks]/SUM(Planned Fraction by Grade)))',
#  'A  Actual in Grade[Ranks]=Total Manpower by Rank[Ranks] ',
#  'A  Actual Fraction in Each Grade[Ranks]=Actual in Grade[Ranks]/POS(Total Strength) ',
#  'A  Total Strength=SUM(Total Manpower by Rank[!]) ',
#  'A  Strength Gap=(Strength Target-Total Strength)/POS(Strength Target)*(1-Switch to Use E3 thru E9 only)+(Strength Target E3 thru E9-Total Strength E3 thru E9)/POS(Strength Target E3 thru E9)*Switch to Use E3 thru E9 only ',
#  'C  Switch to Use E3 thru E9 only=0 ',
#  'A  Strength Target=sum(Target in Grade[!]) ',
#  'A  Strength Target E3 thru E9=sumv(Target in Grade,3,9) ',
#  'A  Total Strength E3 thru E9=SUMV(Total Manpower by Rank,3,9) ',
#  'A  Total of Positive Gaps=Sum(Positive Target in Grade Gap in People[!]) ',
#  'A  Positive Target in Grade Gap in People[Ranks]=_conditional(Switch to Consider Positives Only=1,_conditional(Target in Grade Gap in People[Ranks] > 0,Target in Grade Gap in People[Ranks],0),Target in Grade Gap in People[Ranks])',
#  'C  Switch to Consider Positives Only=1 ',
#  'A  Target in Grade Gap in People[Ranks]=(Target in Grade[Ranks]-Actual in Grade[Ranks])*Multiplier to Include in Gap[Ranks] ',
#  'C  Multiplier to Include in Gap[Ranks]=1 ',
#  'C  Multiplier to Include in Gap[Rank 1]=0',
#  'C  Multiplier to Include in Gap[Rank 2]=0',
#  'A  Positive Gap above Rank[Ranks]=_conditional(Total Strength > 0,Total of Positive Gaps above Rank[Ranks]/Total Strength,0)',
#  'A  Total of Positive Gaps above Rank[Ranks]=sumv(Positive Target in Grade Gap in People[!],Rank Position[Ranks]+1,9) ',
#  'A  Total of Positive Gaps above Rank[Rank 9]=0',
#  'C  Rank Position[Rank 1]=1 ',
#  'C  Rank Position[Rank 2]=2',
#  'C  Rank Position[Rank 3]=3',
#  'C  Rank Position[Rank 4]=4',
#  'C  Rank Position[Rank 5]=5',
#  'C  Rank Position[Rank 6]=6',
#  'C  Rank Position[Rank 7]=7',
#  'C  Rank Position[Rank 8]=8',
#  'C  Rank Position[Rank 9]=9',
#  'A  Positive Gap above Rank in People[Ranks]=sumv(Positive Target in Grade Gap in People[!],Rank Position[Ranks]+1,Rank Position[Ranks]+1) ',
#  'A  Positive Gap above Rank in People[Rank 9]=0',
#  'A  Planned Fraction by Grade[Ranks]=Table for Planned Distribution[Ranks](TIME) ',
#  'T  Table for Planned Distribution[Rank 1]=2e+3,9.4e-2 ',
#  'T  Table for Planned Distribution[Rank 2]=2e+3,1.28e-1',
#  'T  Table for Planned Distribution[Rank 3]=2e+3,2.33e-1',
#  'T  Table for Planned Distribution[Rank 4]=2e+3,2.17e-1',
#  'T  Table for Planned Distribution[Rank 5]=2e+3,1.61e-1',
#  'T  Table for Planned Distribution[Rank 6]=2e+3,8.3e-2',
#  'T  Table for Planned Distribution[Rank 7]=2e+3,5e-2',
#  'T  Table for Planned Distribution[Rank 8]=2e+3,2.2e-2',
#  'T  Table for Planned Distribution[Rank 9]=2e+3,1.1e-2',
#  'A  Target for Total Strength=Table for Total Strength(TIME) ',
#  'T  Table for Total Strength=2.00075e+3,6.305e+3, 2.000833e+3,6.353e+3, 2.000917e+3,6.293e+3, 2.001e+3,6.533e+3, 2.001083e+3,6.66e+3, 2.001167e+3,6.906e+3, 2.00125e+3,6.976e+3, 2.001333e+3,7.186e+3, 2.001417e+3,7.181e+3, 2.0015e+3,7.196e+3, 2.001583e+3,7.215e+3, 2.001667e+3,7.2e+3, 2.00175e+3,7.144e+3, 2.001833e+3,7.188e+3, 2.001917e+3,7.162e+3, 2.002e+3,7.23e+3, 2.002083e+3,7.264e+3, 2.002167e+3,7.272e+3, 2.00225e+3,7.347e+3, 2.002333e+3,7.267e+3, 2.002417e+3,7.262e+3, 2.0025e+3,7.199e+3, 2.002583e+3,7.143e+3, 2.002667e+3,7.049e+3, 2.00275e+3,6.953e+3, 2.002833e+3,6.877e+3, 2.002917e+3,6.844e+3, 2.003e+3,6.847e+3, 2.003083e+3,6.783e+3, 2.003167e+3,6.757e+3, 2.00325e+3,6.805e+3, 2.003333e+3,6.683e+3, 2.003417e+3,6.585e+3, 2.0035e+3,6.486e+3, 2.003583e+3,6.428e+3, 2.003667e+3,6.329e+3, 2.00375e+3,6.214e+3, 2.003833e+3,6.164e+3, 2.003917e+3,6.089e+3, 2.004e+3,6.051e+3, 2.004083e+3,6.022e+3, 2.004167e+3,6e+3, 2.00425e+3,5.942e+3, 2.004333e+3,5.891e+3, 2.004417e
+3, 2.012583e+3,4.567e+3, 2.012667e+3,4.585e+3, 2.01275e+3,4.534e+3, 2.012833e+3,4.489e+3, 2.012917e+3,4.484e+3, 2.013e+3,4.376e+3, 2.013083e+3,4.365e+3, 2.013167e+3,4.41e+3, 2.01325e+3,4.368e+3, 2.013333e+3,4.396e+3, 2.013417e+3,4.403e+3, 2.0135e+3,4.399e+3, 2.013583e+3,4.439e+3, 2.013667e+3,4.485e+3, 2.01375e+3,4.415e+3, 2.013833e+3,4.384e+3, 2.013917e+3,4.395e+3, 2.014e+3,4.399e+3, 2.014083e+3,4.374e+3, 2.014167e+3,4.402e+3, 2.01425e+3,4.425e+3, 2.014333e+3,4.456e+3, 2.014417e+3,4.464e+3, 2.0145e+3,4.451e+3, 2.014583e+3,4.429e+3, 2.014667e+3,4.499e+3, 2.01475e+3,4.433e+3, 2.014833e+3,4.411e+3, 2.014917e+3,4.462e+3, 2.015e+3,4.478e+3, 2.015083e+3,4.449e+3, 2.015167e+3,4.47e+3 ',
#  'C  Switch for Table by Total=0 ',
#  'N  Initial Planned Manning[Ranks]=Data for EPA by Paygrade[Ranks] ',
#  'C  Switch for Constant Manning=0 ',
#  'N  Initial Manpower Available to Fleet[Ranks]=Fraction Manpower in Fleet[Ranks]*Initial Manpower by rank[Ranks] ',
#  'C  Fraction Manpower in Fleet[Ranks]=1 ',
#  'C  Fraction Manpower in Fleet[Rank 1]=0',
#  'C  Fraction Manpower in Fleet[Rank 2]=0',
#  'A  Initial Manpower by rank[Ranks]=_conditional(Switch to Use Actual Initial Manpower[Ranks]=0,Initial Manpower[Ranks],Initial Actual[Ranks])',
#  'C  Switch to Use Actual Initial Manpower[Ranks]=1 ',
#  'C  Switch to Use Actual Initial Manpower[Rank 1]=0',
#  'C  Switch to Use Actual Initial Manpower[Rank 2]=0',
#  'C  Initial Manpower[Rank 3]=509 ',
#  'C  Initial Manpower[Rank 4]=1109',
#  'C  Initial Manpower[Rank 5]=1270',
#  'C  Initial Manpower[Rank 6]=811',
#  'C  Initial Manpower[Rank 7]=606',
#  'C  Initial Manpower[Rank 8]=102',
#  'C  Initial Manpower[Rank 9]=44',
#  'C  Initial Manpower[Rank 1]=100',
#  'C  Initial Manpower[Rank 2]=750',
#  'N  Initial Actual[Ranks]=Data for Inventory by Rank_2[Ranks] ',
#  'N  Initial Manpower In A School Backlog=Initial Manpower In A School*Multiple on Bklg Relative to Students ',
#  'C  Multiple on Bklg Relative to Students=.5 ',
#  'N  Initial Manpower In A School=_conditional(Switch to Initialize A School with Rank2 Data=1,Initial Actual[Rank 2],Input Initial Manpower in A School)',
#  'C  Switch to Initialize A School with Rank2 Data=1 ',
#  'C  Input Initial Manpower in A School=500 ',
#  'A  Data Based Input to Target[Ranks]=_conditional(Switch to Use Actual for Plans=1,Target for Total Strength by Paygrade[Ranks],Plan for Inventory by Paygrade[Ranks])',
#  'C  Switch to Use Actual for Plans=0 ',
#  'A  Target for Total Strength by Paygrade[Ranks]=Data for Inventory by Paygrade[Ranks] ',
#  'A  Plan for Inventory by Paygrade[Ranks]=Data for EPA by Paygrade[Ranks] ',
#  'A  Data for Inventory E3 to E9=_conditional(TIME>Data End,MISSING(),SUMV(Data for Inventory by Paygrade,3,9))',
#  'C  Data End=2015.5 ',
#  'A  Total Manpower by Rank[Ranks]=Manpower in training pipelines by Rank[Ranks]+Manpower in Fleet[Ranks] ',
#  'A  Manpower in training pipelines by Rank[Ranks]=0 ',
#  'A  Manpower in training pipelines by Rank[Rank 1]=0',
#  'A  Manpower in training pipelines by Rank[Rank 2]=Sailors in A School+Switch to Include Pipeline in Manpower Count*A School Student Backlog',
#  'C  Switch to Include Pipeline in Manpower Count=0 ',
#  'A  Total Losses=SUM(Attrition Rate[!])+Attrition from A School Backlog+Attrition from A School ',
#  'A  Expected Attrition Above Rank[Ranks]=sumv(Attrition Rate[!],Rank Position[Ranks]+1,9) ',
#  'A  Expected Attrition Above Rank[Rank 9]=0',
#  'A  Promotion Time Experienced[Ranks]=_conditional(Promotion Rate Out of Rank[Ranks] >0,(Manpower in Fleet[Ranks])/Promotion Rate Out of Rank[Ranks],100000)',
#  'A  Promotion Time Experienced[Rank 9]=10000',
#  'L  Manpower in Fleet[Ranks]=Manpower in Fleet[Ranks]+DT*(-Promotion Rate Out of Rank[Ranks]+Promotions Into Rank[Ranks]+New Grads[Ranks]-Attrition Rate[Ranks]+Additions to Fleet at Rank[Ranks]) ',
#  'N  Manpower in Fleet[Ranks]=Initial Manpower Available to Fleet[Ranks] ',
#  'R  Promotion Rate Out of Rank[Ranks]=_conditional(Manpower in Fleet[Ranks]=0,0,_conditional(Average Time in Grade[Ranks]=0,0,MIN(Desired Promotion Rate[Ranks],Maximum Promotion Rate[Ranks])*Weight for Constraining Promotions[Ranks]+(1-Weight for Constraining Promotions[Ranks])*Desired Promotion Rate[Ranks]))',
#  'R  Promotion Rate Out of Rank[Rank 9]=0',
#  'C  Weight for Constraining Promotions[Ranks]=1 ',
#  'C  Weight for Constraining Promotions[Rank 1]=0',
#  'C  Weight for Constraining Promotions[Rank 2]=0',
#  'C  Weight for Constraining Promotions[Rank 3]=.5',
#  'R  Promotions Into Rank[Ranks]=Promotions In[Ranks] ',
#  'A  Promotions In[Ranks]=SCLPRD(Promotion Rate Out of Rank[!],1,9,Promotion Map[!,Ranks],1) ',
#  'C  Promotion Map[Ranks,RR]=0 ',
#  'C  Promotion Map[Rank 1,Rank 2]=1',
#  'C  Promotion Map[Rank 2,Rank 3]=1',
#  'C  Promotion Map[Rank 3,Rank 4]=1',
#  'C  Promotion Map[Rank 4,Rank 5]=1',
#  'C  Promotion Map[Rank 5,Rank 6]=1',
#  'C  Promotion Map[Rank 6,Rank 7]=1',
#  'C  Promotion Map[Rank 7,Rank 8]=1',
#  'C  Promotion Map[Rank 8,Rank 9]=1',
#  'R  New Grads[Ranks]=Graduates by Rank[Ranks] ',
#  'R  Attrition Rate[Ranks]=(1-Retention Rate[Ranks])*Manpower in Fleet[Ranks] ',
#  'R  Additions to Fleet at Rank[Ranks]=0 ',
#  'A  Recent Losses in Next Rank[Ranks]=SMOOTH(Total Losses in Next Rank[Ranks],DT)*ONE YEAR ',
#  'A  Total Losses in Next Rank[Ranks]=sumv(Attrition Rate[!],Rank Position[Ranks]+1,Rank Position[Ranks]+1) ',
#  'A  Total Losses in Next Rank[Rank 9]=0',
#  'A  Total Continuation Rate=1-Total Overall Loss Rate ',
#  'A  Total Overall Loss Rate=Total Losses from Fleet/Total Manpower in Fleet ',
#  'A  Total Losses from Fleet=SUM(Attrition Rate) ',
#  'A  Overall Retention Gap=SCLPRD(Retention Gap[!],1,9,Total Manpower by Rank[!],1)/POS(SUM(Total Manpower by Rank[!])) ',
#  'A  Retention Gap[Ranks]=Retention Goal[Ranks]-Retention Rate[Ranks] ',
#  'A  Retention Rate[Ranks]=MAX(0,MIN(1,Typical Retention[Ranks]*Effect on Retention of Years of Experience[Ranks]*Effect of Unemployment on Retention*Recent Effect of Incentives on Retention Rate[Ranks]*Effect of Advancement Oppty[Ranks]*Effect of Economic Conditions on Retention)) ',
#  'C  Typical Retention[Rank 1]=0.97 ',
#  'C  Typical Retention[Rank 2]=0.97',
#  'C  Typical Retention[Rank 3]=0.97',
#  'C  Typical Retention[Rank 4]=0.97',
#  'C  Typical Retention[Rank 5]=0.97',
#  'C  Typical Retention[Rank 6]=0.95',
#  'C  Typical Retention[Rank 7]=0.95',
#  'C  Typical Retention[Rank 8]=0.8',
#  'C  Typical Retention[Rank 9]=0.8',
#  'A  Effect on Retention of Years of Experience[Ranks]=Table for Effect on Retention of Years of Exp(Recent Avg Overall Experience by Rank[Ranks]) ',
#  'T  Table for Effect on Retention of Years of Exp=0,1, 2,1, 3,1, 5,1, 8,1, 1.1e+1,9.45e-1, 1.6e+1,9.3e-1, 1.8e+1,8.5e-1, 1.9e+1,8e-1, 2.1e+1,8e-1, 2.2e+1,7e-1, 3e+1,7e-1 ',
#  'A  Recent Avg Overall Experience by Rank[Ranks]=SMOOTH(Avg Overall Experience in Rank[Ranks,allYears],DT) ',
#  'A  Recent Effect of Incentives on Retention Rate[Ranks]=SMOOTH(Effect of Incentives on Retention Rate[Ranks],Time to Smooth Retention Rate) ',
#  'C  Time to Smooth Retention Rate=.25 ',
#  'A  Effect of Incentives on Retention Rate[Ranks]=TUNE1(Table for Effect of Incentives on retention(Actual vs Normal Reenlistment Incentives[Ranks]),Tuner for Effect of Reenlistment Incentives[Ranks]) ',
#  'T  Table for Effect of Incentives on retention=0,9e-1, 1e-2,8.5e-1, 1,1, 2,1.15 ',
#  'C  Tuner for Effect of Reenlistment Incentives[Ranks]=1 ',
#  'C  Tuner for Effect of Reenlistment Incentives[Rank 3]=0',
#  'C  Tuner for Effect of Reenlistment Incentives[Rank 4]=0.25',
#  'A  Effect of Advancement Oppty[Ranks]=TUNE1(T for Effect of Advancement Oppty(Recent Advancement Oppty[Ranks]),Tuner for Effect of Advancement Oppty[Ranks]) ',
#  'N  Effect of Advancement Oppty[Ranks]=1 ',
#  'T  T for Effect of Advancement Oppty=0,9e-1, 2.5e-2,9e-1, 5e-2,9e-1, 7.5e-2,9.5e-1, 1e-1,1, 1,1.05 ',
#  'C  Tuner for Effect of Advancement Oppty[Ranks]=.25 ',
#  'C  Tuner for Effect of Advancement Oppty[Rank 9]=0',
#  'A  Recent Advancement Oppty[Ranks]=SMOOTHI(Advancement Oppty[Ranks],2*DT,.1) ',
#  'A  Advancement Oppty[Ranks]=_conditional(Actual in Grade[Ranks] > 0.1,(Positive Gap above Rank in People[Ranks]+Recent Losses in Next Rank[Ranks])/Actual in Grade[Ranks],1)',
#  'A  Effect of Economic Conditions on Retention=TUNE1(Table for Eff of Economic Conditions on Retention(Economic Conditions),1/Years to Reenlist) ',
#  'T  Table for Eff of Economic Conditions on Retention=-3,1.245, -2,1.169, -1,1.087, -5e-1,1.044, 0,1, 5e-1,9.58e-1, 1,9.18e-1, 2,8.46e-1, 3,7.86e-1 ',
#  'C  Years to Reenlist=6 ',
#  'A  Economic Conditions=Table for Economic Conditions(TIME) ',
#  'T  Table for Economic Conditions=2e+3,0 ',
#  'A  Recent Retention Gap[Ranks]=SMOOTHI(Retention Gap[Ranks],Time to Perceive Gap,0) ',
#  'N  Recent Retention Gap[Ranks]=0 ',
#  'C  Time to Perceive Gap=.25 ',
#  'A  Recent Relative Skill in Rank[Ranks]=Average Skill in Rank[Ranks,allYears] ',
#  'A  Actual vs Normal Reenlistment Incentives[Ranks]=Reenlistment incentives offered per person[Ranks]/Normal Cost per Reenlistment bonus[Ranks] ',
#  'A  Reenlistment incentives offered per person[Ranks]=_conditional(Number of Reenlistments Needed[Ranks] > 0,Reenlistment incentives offered[Ranks]/Number of Reenlistments Needed[Ranks],0)',
#  'A  Reenlistment incentives offered[Ranks]=Number of Reenlistments Needed[Ranks]*Effective Cost per Reenlistment bonus[Ranks]*Effect of Funding Constraint on Reenlistment bonus ',
#  'A  Number of Reenlistments Needed[Ranks]=MAX(0,Recent Retention Gap[Ranks]*Manpower in Fleet[Ranks]) ',
#  'A  Effective Cost per Reenlistment bonus[Ranks]=Normal Cost per Reenlistment bonus[Ranks]*Reenlistment Incentives[Ranks] ',
#  'C  Normal Cost per Reenlistment bonus[Ranks]=10000 ',
#  'A  Reenlistment Incentives[Ranks]=Table for Gap Effect on Incentives(Recent Retention Gap[Ranks]) ',
#  'T  Table for Gap Effect on Incentives=-2e-1,6e-1, -1e-1,8e-1, 0,1, 1e-1,1.2 ',
#  'A  Effect of Funding Constraint on Reenlistment bonus=_conditional(Total Reenlistment bonuses desired > 0,MIN(1,Max Retention Budget/Total Reenlistment bonuses desired),1)',
#  'A  Total Reenlistment bonuses desired=SCLPRD(Number of Reenlistments Needed[!],1,9,Effective Cost per Reenlistment bonus[!],1) ',
#  'A  Retention Goal[Ranks]=MAX(0,MIN(1,Weight for Normal Only*Normal Retention[Ranks]+(1-Weight for Normal Only)*MIN(1,Overall Multiplier[Ranks]*Normal Retention[Ranks]))) ',
#  'C  Weight for Normal Only=0 ',
#  'C  Normal Retention[Rank 1]=0.9 ',
#  'C  Normal Retention[Rank 2]=0.9',
#  'C  Normal Retention[Rank 3]=0.9',
#  'C  Normal Retention[Rank 4]=0.9',
#  'C  Normal Retention[Rank 5]=0.9',
#  'C  Normal Retention[Rank 6]=0.85',
#  'C  Normal Retention[Rank 7]=0.85',
#  'C  Normal Retention[Rank 9]=0.75',
#  'C  Normal Retention[Rank 8]=0.75',
#  'A  Overall Multiplier[Ranks]=Multiplier for Rank Target[Ranks]*Multiplier for Overall Target*Multiplier for Above Rank Targets[Ranks] ',
#  'A  Multiplier for Rank Target[Ranks]=Table for Multiplier for Rank Target(Target in Grade Gap[Ranks]) ',
#  'T  Table for Multiplier for Rank Target=-2e-1,5e-1, -8e-2,6e-1, 0,1, 8e-2,1.4, 2e-1,1.5 ',
#  'A  Multiplier for Overall Target=Table for Multiplier for Overall Strength Target(Strength Gap) ',
#  'T  Table for Multiplier for Overall Strength Target=-2e-1,8.5e-1, 0,1, 2e-1,1.15 ',
#  'A  Multiplier for Above Rank Targets[Ranks]=Table for Multiplier for Overall Strength Target(Positive Gap above Rank[Ranks]) ',
#  'A  Promotion Target Time Gap[Ranks]=Indicated Promotion Time[Ranks]-Target Promotion Time[Ranks] ',
#  'A  Indicated Promotion Time[Ranks]=MAX(Minimum Promotion Time Effect*Normal Promotion Time[Ranks],Weight for Normal Promotion Time[Ranks]*Normal Promotion Time[Ranks]+(1-Weight for Normal Promotion Time[Ranks])*(Normal Promotion Time[Ranks]*Promotion Effect Out of Grade on Grade Target[Ranks]*Promotion Effect Out of Next Grade on Grade Target[Ranks]*Promotion Effect of this Ranks Gap[Ranks])) ',
#  'C  Weight for Normal Promotion Time[Rank 1]=0.5 ',
#  'C  Weight for Normal Promotion Time[Rank 2]=1',
#  'C  Weight for Normal Promotion Time[Rank 3]=0.5',
#  'C  Weight for Normal Promotion Time[Rank 4]=0',
#  'C  Weight for Normal Promotion Time[Rank 5]=0',
#  'C  Weight for Normal Promotion Time[Rank 6]=0',
#  'C  Weight for Normal Promotion Time[Rank 7]=0',
#  'C  Weight for Normal Promotion Time[Rank 8]=0',
#  'C  Weight for Normal Promotion Time[Rank 9]=0',
#  'C  Normal Promotion Time[Rank 2]=0.75 ',
#  'C  Normal Promotion Time[Rank 3]=1.25',
#  'C  Normal Promotion Time[Rank 4]=2.5',
#  'C  Normal Promotion Time[Rank 5]=5.5',
#  'C  Normal Promotion Time[Rank 6]=6',
#  'C  Normal Promotion Time[Rank 8]=5',
#  'C  Normal Promotion Time[Rank 9]=1000',
#  'C  Normal Promotion Time[Rank 1]=0.75',
#  'C  Normal Promotion Time[Rank 7]=7',
#  'C  Minimum Promotion Time Effect=0.5 ',
#  'A  Promotion Effect Out of Grade on Grade Target[Ranks]=Table for Effect on Promotion Time(Next Ranks Gap[Ranks]) ',
#  'T  Table for Effect on Promotion Time=-5e-2,1.5, 0,1, 5e-2,5e-1, 1.5e-1,4e-1, 5e-1,2.5e-1, 1,2e-1 ',
#  'A  Next Ranks Gap[Rank 1]=Target in Grade Gap[Rank 2] ',
#  'A  Next Ranks Gap[Rank 2]=Target in Grade Gap[Rank 3]',
#  'A  Next Ranks Gap[Rank 3]=Target in Grade Gap[Rank 4]',
#  'A  Next Ranks Gap[Rank 4]=Target in Grade Gap[Rank 5]',
#  'A  Next Ranks Gap[Rank 5]=Target in Grade Gap[Rank 6]',
#  'A  Next Ranks Gap[Rank 6]=Target in Grade Gap[Rank 7]',
#  'A  Next Ranks Gap[Rank 7]=Target in Grade Gap[Rank 8]',
#  'A  Next Ranks Gap[Rank 8]=Target in Grade Gap[Rank 9]',
#  'A  Next Ranks Gap[Rank 9]=0',
#  'A  Promotion Effect Out of Next Grade on Grade Target[Ranks]=MIN(1,TUNE1(^Table for Effect on Promotion Time(Second Rank Above Gap[Ranks]),Tuner for Second rank above effect)) ',
#  'C  Tuner for Second rank above effect=.5 ',
#  'A  Second Rank Above Gap[Rank 1]=Next Ranks Gap[Rank 2] ',
#  'A  Second Rank Above Gap[Rank 2]=Next Ranks Gap[Rank 3]',
#  'A  Second Rank Above Gap[Rank 3]=Next Ranks Gap[Rank 4]',
#  'A  Second Rank Above Gap[Rank 4]=Next Ranks Gap[Rank 5]',
#  'A  Second Rank Above Gap[Rank 5]=Next Ranks Gap[Rank 6]',
#  'A  Second Rank Above Gap[Rank 6]=Next Ranks Gap[Rank 7]',
#  'A  Second Rank Above Gap[Rank 7]=Next Ranks Gap[Rank 8]',
#  'A  Second Rank Above Gap[Rank 8]=Next Ranks Gap[Rank 9]',
#  'A  Second Rank Above Gap[Rank 9]=0',
#  'A  Promotion Effect of this Ranks Gap[Ranks]=TUNE1(Table for Effect on Promotion Time(-Target in Grade Gap[Ranks]),Tuner for Current Grade Gap) ',
#  'C  Tuner for Current Grade Gap=1 ',
#  'L  Target Promotion Time[Ranks]=Target Promotion Time[Ranks]+DT*(Adjust to Promotion Time[Ranks]) ',
#  'N  Target Promotion Time[Ranks]=Normal Promotion Time[Ranks] ',
#  'R  Adjust to Promotion Time[Ranks]=Change to Promotion Time[Ranks] ',
#  'A  Change to Promotion Time[Ranks]=Promotion Target Time Gap[Ranks]/Time to Adjust Promotion Time ',
#  'C  Time to Adjust Promotion Time=1 ',
#  'A  Multiplier for promotion by rank[Ranks]=1 ',
#  'A  Multiplier for promotion by rank[Rank 1]=Multiplier for recruiting by rank[Rank 2]',
#  'A  Multiplier for promotion by rank[Rank 2]=Multiplier for recruiting by rank[Rank 3]',
#  'A  Multiplier for promotion by rank[Rank 3]=Multiplier for recruiting by rank[Rank 4]',
#  'A  Multiplier for promotion by rank[Rank 4]=Multiplier for recruiting by rank[Rank 5]',
#  'A  Multiplier for promotion by rank[Rank 5]=Multiplier for recruiting by rank[Rank 6]',
#  'A  Multiplier for promotion by rank[Rank 6]=Multiplier for recruiting by rank[Rank 7]',
#  'A  Multiplier for promotion by rank[Rank 7]=Multiplier for recruiting by rank[Rank 8]',
#  'A  Multiplier for promotion by rank[Rank 8]=Multiplier for recruiting by rank[Rank 9]',
#  'A  Multiplier for recruiting by rank[Ranks]=Multiplier for recruiting by rank for one rank[Ranks] ',
#  'A  Multiplier for recruiting by rank[Rank 3]=Multiplier for recruiting by rank for one rank[Rank 2]*Multiplier for recruiting by rank for one rank[Rank 3]',
#  'A  Multiplier for recruiting by rank[Rank 4]=Multiplier for recruiting by rank for one rank[Rank 2]*Multiplier for recruiting by rank for one rank[Rank 3]*Multiplier for recruiting by rank for one rank[Rank 4]',
#  'A  Multiplier for recruiting by rank[Rank 5]=Multiplier for recruiting by rank for one rank[Rank 2]*Multiplier for recruiting by rank for one rank[Rank 3]*Multiplier for recruiting by rank for one rank[Rank 4]*Multiplier for recruiting by rank for one rank[Rank 5]',
#  'A  Multiplier for recruiting by rank[Rank 6]=Multiplier for recruiting by rank for one rank[Rank 2]*Multiplier for recruiting by rank for one rank[Rank 3]*Multiplier for recruiting by rank for one rank[Rank 4]*Multiplier for recruiting by rank for one rank[Rank 5]*Multiplier for recruiting by rank for one rank[Rank 6]',
#  'A  Multiplier for recruiting by rank[Rank 7]=Multiplier for recruiting by rank for one rank[Rank 2]*Multiplier for recruiting by rank for one rank[Rank 3]*Multiplier for recruiting by rank for one rank[Rank 4]*Multiplier for recruiting by rank for one rank[Rank 5]*Multiplier for recruiting by rank for one rank[Rank 6]*Multiplier for recruiting by rank for one rank[Rank 7]',
#  'A  Multiplier for recruiting by rank[Rank 8]=Multiplier for recruiting by rank for one rank[Rank 2]*Multiplier for recruiting by rank for one rank[Rank 3]*Multiplier for recruiting by rank for one rank[Rank 4]*Multiplier for recruiting by rank for one rank[Rank 5]*Multiplier for recruiting by rank for one rank[Rank 6]*Multiplier for recruiting by rank for one rank[Rank 7]*Multiplier for recruiting by rank for one rank[Rank 8]',
#  'A  Multiplier for recruiting by rank[Rank 9]=Multiplier for recruiting by rank for one rank[Rank 2]*Multiplier for recruiting by rank for one rank[Rank 3]*Multiplier for recruiting by rank for one rank[Rank 4]*Multiplier for recruiting by rank for one rank[Rank 5]*Multiplier for recruiting by rank for one rank[Rank 6]*Multiplier for recruiting by rank for one rank[Rank 7]*Multiplier for recruiting by rank for one rank[Rank 8]*Multiplier for recruiting by rank for one rank[Rank 9]',
#  'A  Multiplier for recruiting by rank for one rank[Rank 1]=1 ',
#  'A  Multiplier for recruiting by rank for one rank[Rank 2]=1/EXP(Normal Promotion Time[Rank 1]*LOGN(Normal Retention[Rank 1]))',
#  'A  Multiplier for recruiting by rank for one rank[Rank 3]=1/EXP(Normal Promotion Time[Rank 2]*LOGN(Normal Retention[Rank 2]))',
#  'A  Multiplier for recruiting by rank for one rank[Rank 4]=1/EXP(Normal Promotion Time[Rank 3]*LOGN(Normal Retention[Rank 3]))',
#  'A  Multiplier for recruiting by rank for one rank[Rank 5]=1/EXP(Normal Promotion Time[Rank 4]*LOGN(Normal Retention[Rank 4]))',
#  'A  Multiplier for recruiting by rank for one rank[Rank 6]=1/EXP(Normal Promotion Time[Rank 5]*LOGN(Normal Retention[Rank 5]))',
#  'A  Multiplier for recruiting by rank for one rank[Rank 7]=1/EXP(Normal Promotion Time[Rank 6]*LOGN(Normal Retention[Rank 6]))',
#  'A  Multiplier for recruiting by rank for one rank[Rank 8]=1/EXP(Normal Promotion Time[Rank 7]*LOGN(Normal Retention[Rank 7]))',
#  'A  Multiplier for recruiting by rank for one rank[Rank 9]=1/EXP(Normal Promotion Time[Rank 8]*LOGN(Normal Retention[Rank 8]))',
#  'A  Desired Promotion Rate[Ranks]=Manpower in Fleet[Ranks]/Average Time in Grade[Ranks] ',
#  'A  Average Time in Grade[Ranks]=_conditional(Manpower in Fleet[Ranks]=0,1,Actual Promotion Time[Ranks])',
#  'A  Average Time in Grade[Rank 9]=1/(1-Retention Rate[Rank 9])',
#  'A  Actual Promotion Time[Ranks]=Target Promotion Time[Ranks] ',
#  'A  Maximum Promotion Rate[Ranks]=(1+Maximum Fraction over Indicated)*(MAX(0,(((Total of Positive Gaps above Rank[Ranks])*Multiplier for promotion by rank[Ranks])/Minimum Time for Promotions+Expected Attrition Above Rank[Ranks])))*Effect of ASVAB scores on Promotion rate[Ranks] ',
#  'A  Maximum Promotion Rate[Rank 9]=0',
#  'C  Maximum Fraction over Indicated=0 ',
#  'C  Minimum Time for Promotions=.25 ',
#  'A  Effect of ASVAB scores on Promotion rate[Ranks]=Table for Effect of ASVAB on Promotion(Average ASVAB in Rank[Ranks]) ',
#  'T  Table for Effect of ASVAB on Promotion=0,1e-1, 5e+1,1, 1e+2,1 ',
#  'C  ONE YEAR=1 ',
#  'C  ONE PERSON=1 ',
#  'A  Data for Recruiters=_conditional(TIME<2006 or TIME>2011,MISSING(),Recruiters Data(TIME))',
#  'T  Recruiters Data=2.005e+3,4e+3, 2.006e+3,3.1e+3, 2.007e+3,3.1e+3, 2.008e+3,3.2e+3, 2.009e+3,3.7e+3, 2.01e+3,4e+3 ',
#  'A  Data for Recruiters HQ Productivity=_conditional(TIME>=2005 and TIME<=2011,Recruiter Productivity(TIME),MISSING())',
#  'T  Recruiter Productivity=2.005e+3,7.5, 2.006e+3,1.05e+1, 2.007e+3,1e+1, 2.008e+3,1.1e+1, 2.009e+3,1.05e+1, 2.01e+3,8 ',
#  'A  Data for NPS Navy Contracts=_conditional(TIME>=2012 or TIME<2005,MISSING(),Total NPS Navy Contracts(TIME))',
#  'T  Total NPS Navy Contracts=2.005e+3,4.5e+4, 2.006e+3,4.7e+4, 2.007e+3,4.8e+4, 2.008e+3,5.2e+4, 2.009e+3,5.1e+4, 2.01e+3,3.9e+4 ',
#  'A  Data for Average Enlistment Bonus=_conditional(TIME>=2011.75 or TIME<2007.75,MISSING(),Average Navy Enlistement Bonus(TIME))',
#  'T  Average Navy Enlistement Bonus=2.00375e+3,8e+3, 2.00475e+3,9e+3, 2.00575e+3,4e+3, 2.00675e+3,7e+3, 2.00775e+3,6.5e+3, 2.00875e+3,6e+3, 2.00975e+3,5e+3, 2.01075e+3,4e+3 ',
#  'A  Data for Recruiting Goal=_conditional(TIME>2015.75,MISSING(),Recruiting Goal Table(TIME))',
#  'T  Recruiting Goal Table=2.00475e+3,3e+3, 2.00575e+3,1.766e+3, 2.00675e+3,1.604e+3, 2.00775e+3,5.98e+2, 2.00875e+3,9.53e+2, 2.00975e+3,8.76e+2, 2.01075e+3,6.6e+2, 2.01175e+3,5.68e+2, 2.01275e+3,5.39e+2, 2.01375e+3,6.5e+2, 2.01475e+3,8.02e+2 ',
#  'A  Data for Total Billets=_conditional(TIME>Data End,MISSING(),SUM(Data for Billet by Paygrade))',
#  'A  Data for Billet by Paygrade[Ranks]=Data for Sea Billets by Rank[Ranks]+Data for Shore Billets by Rank[Ranks]+Data for Student Billets by Rank[Ranks] ',
#  'A  Data for Inventory Totalled=_conditional(TIME>Data End,MISSING(),SUM(Data for Inventory by Paygrade))',
#  'A  Data for Inventory by Paygrade[Ranks]=Data for Inventory by Rank[Ranks] ',
#  'A  EPA as Planned E3 thu E9=_conditional(TIME>Data End,MISSING(),SUMV(Data for EPA by Paygrade 3yrs Out,3,9))',
#  'A  Data for EPA by Paygrade 3yrs Out[Ranks]=Data for EPA by Rank p3 years[Ranks] ',
#  'A  Data for Total EPA with MISSING=_conditional(TIME>Data End,MISSING(),Data for Total EPA)',
#  'A  Data for Total EPA=SUM(Data for EPA by Paygrade) ',
#  'A  Data for EPA by Paygrade[Ranks]=Data for EPA by Rank[Ranks] ',
#  'A  Data for Billet by Paygrade MISSING[Ranks]=_conditional(TIME>Data End,MISSING(),Data for Billet by Paygrade[Ranks])',
#  'A  Data for EPA by Paygrade MISSING[Ranks]=_conditional(TIME>Data End,MISSING(),Data for EPA by Paygrade[Ranks])',
#  'A  Data for Inventory by Paygrade MISSING[Ranks]=_conditional(TIME>Data End,MISSING(),Data for Inventory by Paygrade[Ranks])',
#  'A  Data for Inventory by Rank_2[Ranks]=SUM(Data for Inventory by LOS and Rank[!,Ranks]) ',
#  'A  Data for Inventory Total=SUM(Data for Inventory by LOS) ',
#  'A  Data for Inventory by LOS[LOS]=SUM(Data for Inventory by LOS and Rank[LOS,!]) ',
#  'A  Data for Inventory by LOS and Rank[LOS,Ranks]=Data Table for Inventory by LOS and Rank[LOS,Ranks](TIME) ',
#  'T  Data Table for Inventory by LOS and Rank[1,Rank 1]=2.006082e+3,7, 2.006157e+3,6, 2.006249e+3,8, 2.006329e+3,3, 2.006416e+3,4, 2.006496e+3,3, 2.006582e+3,3, 2.006666e+3,2, 2.006746e+3,0, 2.006832e+3,5, 2.006913e+3,5, 2.006999e+3,4, 2.007082e+3,4, 2.007157e+3,4, 2.007249e+3,8, 2.007329e+3,9, 2.007416e+3,1.3e+1, 2.007496e+3,7, 2.007582e+3,3, 2.007666e+3,2, 2.007746e+3,1, 2.007832e+3,1, 2.007913e+3,4, 2.007999e+3,5, 2.008082e+3,6, 2.00816e+3,4, 2.008249e+3,5, 2.008329e+3,1, 2.008416e+3,2, 2.008496e+3,0, 2.008582e+3,2, 2.008666e+3,1, 2.008746e+3,6, 2.008832e+3,3, 2.008913e+3,2, 2.008999e+3,2, 2.009082e+3,2, 2.009157e+3,0, 2.009249e+3,0, 2.009329e+3,0, 2.009416e+3,1, 2.009496e+3,2, 2.009582e+3,1, 2.009666e+3,1, 2.009746e+3,0, 2.009832e+3,2, 2.009913e+3,1, 2.009999e+3,3, 2.010082e+3,2, 2.010157e+3,2, 2.010249e+3,2, 2.010329e+3,4, 2.010416e+3,4, 2.010496e
.009913e+3,0, 2.009999e+3,1, 2.010082e+3,2, 2.010157e+3,2, 2.010249e+3,2, 2.010329e+3,2, 2.010416e+3,2, 2.010496e+3,3, 2.010582e+3,3, 2.010666e+3,3, 2.010746e+3,5, 2.010832e+3,1, 2.010913e+3,1, 2.010999e+3,1, 2.011082e+3,1, 2.011157e+3,1, 2.011249e+3,1, 2.011329e+3,2, 2.011416e+3,2, 2.011496e+3,3, 2.011582e+3,3, 2.011666e+3,3, 2.011746e+3,4, 2.011832e+3,8, 2.011913e+3,1.2e+1, 2.011999e+3,1.2e+1, 2.012082e+3,1.4e+1, 2.01216e+3,1.7e+1, 2.012249e+3,1.7e+1, 2.012329e+3,1.9e+1, 2.012416e+3,2e+1, 2.012496e+3,2.3e+1, 2.012582e+3,2.3e+1, 2.012666e+3,2.4e+1, 2.012746e+3,2.8e+1, 2.012832e+3,7, 2.012913e+3,1e+1, 2.012999e+3,1.2e+1, 2.013082e+3,1.3e+1, 2.013157e+3,1.3e+1, 2.013249e+3,1.4e+1, 2.013329e+3,1.4e+1, 2.013416e+3,1.4e+1, 2.013496e+3,1.4e+1, 2.013582e+3,1.4e+1, 2.013746e+3,1.5e+1, 2.013832e+3,1, 2.013913e+3,2, 2.013999e+3,2, 2.014082e+3,3, 2.014157e+3,3, 2.014249e+3,4, 2.014329e+3,4, 2.014416e+3,7, 2.014496e+3,7, 2.014582e+3,7, 2.014666e+3,8, 2.014746e+3,8, 2.014832e+3,4, 2.014913e+3,0, 2.014999e+3,0, 2.015082e+3,1, 2.015157e+3,1, 2.015249e+3,1, 2.015329e+3,1, 2.015416e+3,1, 2.015496e+3,1',
#  ...]

# %%
def parse_general_expression(element, namespace=None, subscript_dict=None):
    
    if namespace is None:
        namespace = {}
    if subscript_dict is None:
        subscript_dict = {}

    functions = functiondic

    builders = {
        "integ": lambda expr, init: builder.add_stock(element['py_name'], element['subs'],
                                                      expr, init, subscript_dict),
        "delay1": lambda in_var, dtime: builder.add_n_delay(in_var, dtime, '0', '1',
                                                            element['subs'], subscript_dict),
        "delay1i": lambda in_var, dtime, init: builder.add_n_delay(in_var, dtime, init, '1',
                                                                   element['subs'], subscript_dict),
        "delay3": lambda in_var, dtime: builder.add_n_delay(in_var, dtime, '0', '3',
                                                            element['subs'], subscript_dict),
        "delay3i": lambda in_var, dtime, init: builder.add_n_delay(in_var, dtime, init, '3',
                                                                   element['subs'], subscript_dict),
        "delay n": lambda in_var, dtime, init, order: builder.add_n_delay(in_var, dtime,
                                                                          init, order,
                                                                          element['subs'],
                                                                          subscript_dict),
        "smooth": lambda in_var, dtime: builder.add_n_smooth(in_var, dtime, '0', '1',
                                                             element['subs'], subscript_dict),
        "smoothi": lambda in_var, dtime, init: builder.add_n_smooth(in_var, dtime, init, '1',
                                                                    element['subs'],
                                                                    subscript_dict),
        "smooth3": lambda in_var, dtime: builder.add_n_smooth(in_var, dtime, '0', '3',
                                                              element['subs'], subscript_dict),
        "smooth3i": lambda in_var, dtime, init: builder.add_n_smooth(in_var, dtime, init, '3',
                                                                     element['subs'],
                                                                     subscript_dict),
        "smooth n": lambda in_var, dtime, init, order: builder.add_n_smooth(in_var, dtime,
                                                                            init, order,
                                                                            element['subs'],
                                                                            subscript_dict),
        "initial": lambda initial_input: builder.add_initial(initial_input)
    }

    in_ops = {
        "+": "+", "-": "-", "*": "*", "/": "/", "^": "**", "=": "==", "<=": "<=", "<>": "!=",
        "<": "<", ">=": ">=", ">": ">",
        ":and:": " and ", ":or:": " or "}  # spaces important for word-based operators

    pre_ops = {
        "-": "-", ":not:": " not ",  # spaces important for word-based operators
        "+": " "  # space is important, so that and empty string doesn't slip through generic
    }

    # in the following, if lists are empty use non-printable character
    # everything needs to be escaped before going into the grammar, in case it includes quotes
    sub_names_list = [re.escape(x) for x in subscript_dict.keys()] or ['\\a']
    sub_elems_list = [re.escape(y) for x in subscript_dict.values() for y in x] or ['\\a']
    ids_list = [re.escape(x) for x in namespace.keys()] or ['\\a']
    in_ops_list = [re.escape(x) for x in in_ops.keys()]
    pre_ops_list = [re.escape(x) for x in pre_ops.keys()]

    expression_grammar = r"""
    expr_type = array / expr
    expr = _ pre_oper? _ (lookup_def / build_call / call / parens / number / reference) _ (in_oper _ expr)?

    lookup_def = ~r"(WITH\ LOOKUP)"I _ "(" _ reference _ "," _ "(" _  ("[" ~r"[^\]]*" "]" _ ",")?  ( "(" _ expr _ "," _ expr _ ")" ","? _ )+ _ ")" _ ")"
    call = (func / id) _ "(" _ (expr _ ","? _)* ")" # allows calls with no arguments
    build_call = builder _ "(" _ (expr _ ","? _)* ")" # allows calls with no arguments
    parens   = "(" _ expr _ ")"

    reference = id _ subscript_list?
    subscript_list = "[" _ ((sub_name / sub_element) _ ","? _)+ "]"

    array = (number _ ("," / ";")? _)+ !~r"."  # negative lookahead for anything other than an array
    number = ~r"\d+\.?\d*(e[+-]\d+)?"

    id = ~r"(%(ids)s)"I
    sub_name = ~r"(%(sub_names)s)"I  # subscript names (if none, use non-printable character)
    sub_element = ~r"(%(sub_elems)s)"I  # subscript elements (if none, use non-printable character)

    func = ~r"(%(funcs)s)"I  # functions (case insensitive)
    in_oper = ~r"(%(in_ops)s)"I  # infix operators (case insensitive)
    pre_oper = ~r"(%(pre_ops)s)"I  # prefix operators (case insensitive)
    builder = ~r"(%(builders)s)"I  # builder functions (case insensitive)

    _ = ~r"[\s\\]*"  # whitespace character
    """ % {
        # In the following, we have to sort keywords in decreasing order of length so that the
        # peg parser doesn't quit early when finding a partial keyword
        'sub_names': '|'.join(reversed(sorted(sub_names_list, key=len))),
        'sub_elems': '|'.join(reversed(sorted(sub_elems_list, key=len))),
        'ids': '|'.join(reversed(sorted(ids_list, key=len))),
        'funcs': '|'.join(reversed(sorted(functions.keys(), key=len))),
        'in_ops': '|'.join(reversed(sorted(in_ops_list, key=len))),
        'pre_ops': '|'.join(reversed(sorted(pre_ops_list, key=len))),
        'builders': '|'.join(reversed(sorted(builders.keys(), key=len))),
    }

    parser = parsimonious.Grammar(expression_grammar)
    tree = parser.parse(element['expr'])

    class ExpressionParser(parsimonious.NodeVisitor):
        # Todo: at some point, we could make the 'kind' identification recursive on expression,
        # so that if an expression is passed into a builder function, the information
        # about whether it is a constant, or calls another function, goes with it.
        def __init__(self, ast):
            self.translation = ""
            self.kind = 'constant'  # change if we reference anything else
            self.new_structure = []
            self.visit(ast)

        def visit_expr_type(self, n, vc):
            s = ''.join(filter(None, vc)).strip()
            self.translation = s

        def visit_expr(self, n, vc):
            s = ''.join(filter(None, vc)).strip()
            self.translation = s
            return s

        def visit_func(self, n, vc):
            self.kind = 'component'
            return functions[n.text.lower()]

        def visit_in_oper(self, n, vc):
            return in_ops[n.text.lower()]

        def visit_pre_oper(self, n, vc):
            return pre_ops[n.text.lower()]

        def visit_reference(self, n, vc):
            self.kind = 'component'
            id_str = vc[0]
            return id_str + '()'

        def visit_id(self, n, vc):
            return namespace[n.text]

        def visit_lookup_def(self, n, vc):
            """ This exists because vensim has multiple ways of doing lookups.
            Which is frustrating."""
            x_val = vc[4]
            pairs = vc[11]
            mixed_list = pairs.replace('(', '').replace(')', '').split(',')
            xs = mixed_list[::2]
            ys = mixed_list[1::2]
            string = "functions.lookup(%(x)s, [%(xs)s], [%(ys)s])" % {
                'x': x_val,
                'xs': ','.join(xs),
                'ys': ','.join(ys)
            }
            return string

        def visit_array(self, n, vc):
            if 'subs' in element and element['subs']:  # first test handles when subs is not defined
                coords = utils.make_coord_dict(element['subs'], subscript_dict, terse=False)
                dims = [utils.find_subscript_name(subscript_dict, sub) for sub in element['subs']]
                shape = [len(coords[dim]) for dim in dims]
                if ';' in n.text or ',' in n.text:
                    text = n.text.strip(';').replace(' ', '').replace(';', ',')
                    data = np.array([float(s) for s in text.split(',')]).reshape(shape)
                else:
                    data = np.tile(float(n.text), shape)
                datastr = np.array2string(data, separator=',').replace('\n', '').replace(' ', '')
                return textwrap.dedent("""\
                    xr.DataArray(data=%(datastr)s,
                                 coords=%(coords)s,
                                 dims=%(dims)s )""" % {
                    'datastr': datastr,
                    'coords': repr(coords),
                    'dims': repr(dims)})

            else:
                return n.text.replace(' ', '')

        def visit_subscript_list(self, n, vc):
            refs = vc[2]
            subs = [x.strip() for x in refs.split(',')]
            coordinates = utils.make_coord_dict(subs, subscript_dict)
            if len(coordinates):
                return '.loc[%s]' % repr(coordinates)
            else:
                return ' '

        def visit_build_call(self, n, vc):
            call = vc[0]
            args = vc[4]
            self.kind = 'component'
            arglist = [x.strip() for x in args.split(',')]
            name, structure = builders[call.strip().lower()](*arglist)
            self.new_structure += structure
            return name

        def visit__(self, n, vc):
            """ Handles whitespace characters"""
            return ''

        def generic_visit(self, n, vc):
            return ''.join(filter(None, vc)) or n.text

    parse_object = ExpressionParser(tree)

    return ({'py_expr': parse_object.translation,
             'kind': parse_object.kind,
             'arguments': ''},
            parse_object.new_structure)

# %%
import pysd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-e69a5215f3f3> in <module>()
# ----> 1 import pysd
#
# C:\Users\BOSMY\Documents\GitHub\pysd\pysd\pysd\pysd.py in <module>()
#      17 import imp
#      18 import time
# ---> 19 from . import utils
#      20 from . import functions
#      21 import warnings
#
# ValueError: Attempted relative import in non-package
